# %%
import torch
import sys
sys.path.append("..")

# %%
# #Install virtual env 
# python -m pip install --user enviroment_setup
# echo "create env"
# python -m venv vertex_venv
# #Add kernel to jupyter
# echo "Add kernel to jupyter"
# ipython kernel install --name "vertex_env" --user

# %%
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
# conda env create -f ../environment_setup-Copy1.yml
# Out:
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# Downloading and Extracting Packages
# sphinxcontrib-htmlhe | 32 KB     | ##################################### | 100%
# jpeg-9e              | 262 KB    | ##################################### | 100%
# debugpy-1.5.1        | 1.7 MB    | ##################################### | 100%
# sqlite-3.41.1        | 1.2 MB    | ##################################### | 100%
# dbus-1.13.18         | 504 KB    | ##################################### | 100%
# _openmp_mutex-5.1    | 21 KB     | ##################################### | 100%
# libgcc-ng-11.2.0     | 5.3 MB    | ##################################### | 100%
# libxslt-1.1.35       | 453 KB    | ##################################### | 100%
# matplotlib-inline-0. | 12 KB     | ##################################### | 100%
# alabaster-0.7.12     | 16 KB     | ##################################### | 100%
# cookiecutter-1.7.2   | 86 KB     | ##################################### | 100%
# zipp-3.7.0           | 12 KB     | ##################################### | 100%
# pyls-spyder-0.4.0    | 11 KB     | ##################################### | 100%
# torchaudio-0.11.0    | 5.2 MB    | ##################################### | 100%
# docutils-0.17.1      | 686 KB    | ##################################### | 100%
# markupsafe-1.1.1     | 33 KB     | ##################################### | 100%
# arrow-0.13.1         | 81 KB     | ##################################### | 100%
# jinja2-2.11.3        | 101 KB    | ##################################### | 100%
# snowballstemmer-2.2. | 61 KB     | ##################################### | 100%
# autopep8-1.6.0       | 42 KB     | ##################################### | 100%
# nbformat-5.1.3       | 44 KB     | ##################################### | 100%
# pcre-8.45            | 207 KB    | ##################################### | 100%
# python-lsp-black-1.0 | 8 KB      | ##################################### | 100%
# bcrypt-3.2.0         | 41 KB     | ##################################### | 100%
# libpng-1.6.39        | 304 KB    | ##################################### | 100%
# readline-8.2         | 357 KB    | ##################################### | 100%
# jinja2-time-0.2.0    | 17 KB     | ##################################### | 100%
# backcall-0.2.0       | 13 KB     | ##################################### | 100%
# libllvm10-10.0.1     | 22.1 MB   | ##################################### | 100%
# pathspec-0.7.0       | 26 KB     | ##################################### | 100%
# ipykernel-6.15.2     | 190 KB    | ##################################### | 100%
# attrs-21.4.0         | 51 KB     | ##################################### | 100%
# fontconfig-2.14.1    | 281 KB    | ##################################### | 100%
# pyqt-5.15.7          | 5.1 MB    | ##################################### | 100%
# bleach-4.1.0         | 123 KB    | ##################################### | 100%
# webencodings-0.5.1   | 20 KB     | ##################################### | 100%
# diff-match-patch-202 | 35 KB     | ##################################### | 100%
# nettle-3.7.3         | 809 KB    | ##################################### | 100%
# numpydoc-1.2         | 45 KB     | ##################################### | 100%
# ipython-8.8.0        | 1.0 MB    | ##################################### | 100%
# mkl_fft-1.3.1        | 180 KB    | ##################################### | 100%
# munkres-1.1.4        | 13 KB     | ##################################### | 100%
# pycparser-2.21       | 94 KB     | ##################################### | 100%
# pytorch-mutex-1.0    | 3 KB      | ##################################### | 100%
# ujson-5.4.0          | 44 KB     | ##################################### | 100%
# cpuonly-2.0          | 2 KB      | ##################################### | 100%
# nbclient-0.5.11      | 62 KB     | ##################################### | 100%
# fonttools-4.25.0     | 632 KB    | ##################################### | 100%
# text-unidecode-1.3   | 65 KB     | ##################################### | 100%
# mypy_extensions-0.4. | 10 KB     | ##################################### | 100%
# pytz-2021.3          | 171 KB    | ##################################### | 100%
# qtpy-1.11.2          | 37 KB     | ##################################### | 100%
# numpy-base-1.23.5    | 6.7 MB    | ##################################### | 100%
# pygments-2.11.2      | 759 KB    | ##################################### | 100%
# rope-0.22.0          | 129 KB    | ##################################### | 100%
# _libgcc_mutex-0.1    | 3 KB      | ##################################### | 100%
# libwebp-base-1.2.4   | 376 KB    | ##################################### | 100%
# intel-openmp-2021.4. | 4.2 MB    | ##################################### | 100%
# icu-58.2             | 10.5 MB   | ##################################### | 100%
# glib-2.69.1          | 1.9 MB    | ##################################### | 100%
# libxml2-2.9.14       | 718 KB    | ##################################### | 100%
# libbrotlienc-1.0.9   | 264 KB    | ##################################### | 100%
# pydocstyle-6.1.1     | 36 KB     | ##################################### | 100%
# click-8.0.4          | 151 KB    | ##################################### | 100%
# importlib_metadata-4 | 12 KB     | ##################################### | 100%
# pluggy-1.0.0         | 28 KB     | ##################################### | 100%
# qtawesome-1.0.3      | 761 KB    | ##################################### | 100%
# brotli-1.0.9         | 18 KB     | ##################################### | 100%
# qtconsole-5.2.2      | 92 KB     | ##################################### | 100%
# pytorch-1.11.0       | 62.9 MB   | ##################################### | 100%
# defusedxml-0.7.1     | 23 KB     | ##################################### | 100%
# nss-3.74             | 1.9 MB    | ##################################### | 100%
# three-merge-0.1.1    | 10 KB     | ##################################### | 100%
# jupyter_client-6.1.1 | 88 KB     | ##################################### | 100%
# pycodestyle-2.7.0    | 41 KB     | ##################################### | 100%
# ffmpeg-4.3           | 9.9 MB    | ##################################### | 100%
# astroid-2.6.6        | 309 KB    | ##################################### | 100%
# libwebp-1.2.4        | 86 KB     | ##################################### | 100%
# libevent-2.1.12      | 425 KB    | ##################################### | 100%
# libpq-12.9           | 2.1 MB    | ##################################### | 100%
# cffi-1.15.1          | 241 KB    | ##################################### | 100%
# sphinxcontrib-qthelp | 26 KB     | ##################################### | 100%
# python-slugify-5.0.2 | 13 KB     | ##################################### | 100%
# packaging-21.3       | 36 KB     | ##################################### | 100%
# yapf-0.31.0          | 126 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 323 KB    | ##################################### | 100%
# libffi-3.4.2         | 136 KB    | ##################################### | 100%
# gstreamer-1.14.1     | 1.7 MB    | ##################################### | 100%
# tornado-6.2          | 590 KB    | ##################################### | 100%
# imagesize-1.3.0      | 9 KB      | ##################################### | 100%
# jupyter_core-4.11.2  | 80 KB     | ##################################### | 100%
# bzip2-1.0.8          | 78 KB     | ##################################### | 100%
# charset-normalizer-2 | 35 KB     | ##################################### | 100%
# ptyprocess-0.7.0     | 17 KB     | ##################################### | 100%
# traitlets-5.1.1      | 84 KB     | ##################################### | 100%
# sortedcontainers-2.4 | 26 KB     | ##################################### | 100%
# stack_data-0.2.0     | 22 KB     | ##################################### | 100%
# sphinxcontrib-appleh | 29 KB     | ##################################### | 100%
# lazy-object-proxy-1. | 30 KB     | ##################################### | 100%
# lcms2-2.12           | 312 KB    | ##################################### | 100%
# libgomp-11.2.0       | 474 KB    | ##################################### | 100%
# libidn2-2.3.2        | 81 KB     | ##################################### | 100%
# zlib-1.2.13          | 103 KB    | ##################################### | 100%
# pysocks-1.7.1        | 31 KB     | ##################################### | 100%
# zstd-1.5.4           | 637 KB    | ##################################### | 100%
# poyo-0.5.0           | 17 KB     | ##################################### | 100%
# qt-webengine-5.15.9  | 47.1 MB   | ##################################### | 100%
# jedi-0.18.1          | 982 KB    | ##################################### | 100%
# wrapt-1.12.1         | 50 KB     | ##################################### | 100%
# expat-2.4.9          | 156 KB    | ##################################### | 100%
# gst-plugins-base-1.1 | 2.2 MB    | ##################################### | 100%
# urllib3-1.26.8       | 106 KB    | ##################################### | 100%
# cryptography-38.0.4  | 1.4 MB    | ##################################### | 100%
# libiconv-1.16        | 736 KB    | ##################################### | 100%
# krb5-1.19.4          | 1.3 MB    | ##################################### | 100%
# qstylizer-0.1.10     | 17 KB     | ##################################### | 100%
# requests-2.27.1      | 54 KB     | ##################################### | 100%
# python-lsp-jsonrpc-1 | 10 KB     | ##################################### | 100%
# lame-3.100           | 323 KB    | ##################################### | 100%
# nspr-4.33            | 222 KB    | ##################################### | 100%
# pyflakes-2.3.1       | 60 KB     | ##################################### | 100%
# sphinxcontrib-serial | 25 KB     | ##################################### | 100%
# wheel-0.37.1         | 33 KB     | ##################################### | 100%
# freetype-2.12.1      | 626 KB    | ##################################### | 100%
# six-1.16.0           | 18 KB     | ##################################### | 100%
# pyrsistent-0.18.0    | 94 KB     | ##################################### | 100%
# toml-0.10.2          | 20 KB     | ##################################### | 100%
# pyqt5-sip-12.11.0    | 87 KB     | ##################################### | 100%
# sphinx-4.4.0         | 1.2 MB    | ##################################### | 100%
# libdeflate-1.17      | 69 KB     | ##################################### | 100%
# torchvision-0.12.0   | 23.4 MB   | ##################################### | 100%
# atomicwrites-1.4.0   | 11 KB     | ##################################### | 100%
# black-19.10b0        | 86 KB     | ##################################### | 100%
# isort-5.9.3          | 83 KB     | ##################################### | 100%
# nest-asyncio-1.5.1   | 10 KB     | ##################################### | 100%
# ca-certificates-2023 | 120 KB    | ##################################### | 100%
# gnutls-3.6.15        | 1.0 MB    | ##################################### | 100%
# flake8-3.9.2         | 129 KB    | ##################################### | 100%
# textdistance-4.2.1   | 29 KB     | ##################################### | 100%
# blas-1.0             | 6 KB      | ##################################### | 100%
# mccabe-0.6.1         | 15 KB     | ##################################### | 100%
# typing_extensions-3. | 31 KB     | ##################################### | 100%
# binaryornot-0.4.4    | 351 KB    | ##################################### | 100%
# python-dateutil-2.8. | 233 KB    | ##################################### | 100%
# asttokens-2.0.5      | 20 KB     | ##################################### | 100%
# pyzmq-23.2.0         | 448 KB    | ##################################### | 100%
# inflection-0.5.1     | 12 KB     | ##################################### | 100%
# cycler-0.11.0        | 12 KB     | ##################################### | 100%
# libxkbcommon-1.0.1   | 483 KB    | ##################################### | 100%
# python-lsp-server-1. | 41 KB     | ##################################### | 100%
# chardet-4.0.0        | 194 KB    | ##################################### | 100%
# paramiko-2.8.1       | 139 KB    | ##################################### | 100%
# libxcb-1.15          | 505 KB    | ##################################### | 100%
# typed-ast-1.4.3      | 185 KB    | ##################################### | 100%
# zeromq-4.3.4         | 331 KB    | ##################################### | 100%
# openssl-1.1.1t       | 3.7 MB    | ##################################### | 100%
# entrypoints-0.3      | 10 KB     | ##################################### | 100%
# libstdcxx-ng-11.2.0  | 4.7 MB    | ##################################### | 100%
# xz-5.2.10            | 429 KB    | ##################################### | 100%
# giflib-5.2.1         | 80 KB     | ##################################### | 100%
# libbrotlidec-1.0.9   | 31 KB     | ##################################### | 100%
# gmp-6.2.1            | 544 KB    | ##################################### | 100%
# libunistring-0.9.10  | 536 KB    | ##################################### | 100%
# tinycss-0.4          | 39 KB     | ##################################### | 100%
# libuuid-1.41.5       | 27 KB     | ##################################### | 100%
# intervaltree-3.1.0   | 25 KB     | ##################################### | 100%
# regex-2022.7.9       | 334 KB    | ##################################### | 100%
# importlib-metadata-4 | 40 KB     | ##################################### | 100%
# prompt-toolkit-3.0.2 | 259 KB    | ##################################### | 100%
# numpy-1.23.5         | 10 KB     | ##################################### | 100%
# ncurses-6.4          | 914 KB    | ##################################### | 100%
# pickleshare-0.7.5    | 13 KB     | ##################################### | 100%
# colorama-0.4.4       | 21 KB     | ##################################### | 100%
# pynacl-1.5.0         | 1.1 MB    | ##################################### | 100%
# sphinxcontrib-jsmath | 8 KB      | ##################################### | 100%
# decorator-5.1.1      | 12 KB     | ##################################### | 100%
# mkl-2021.4.0         | 142.6 MB  | ##################################### | 100%
# tk-8.6.12            | 3.0 MB    | ##################################### | 100%
# whichcraft-0.6.1     | 11 KB     | ##################################### | 100%
# pylint-2.9.6         | 488 KB    | ##################################### | 100%
# pyparsing-3.0.4      | 81 KB     | ##################################### | 100%
# executing-0.8.3      | 18 KB     | ##################################### | 100%
# qdarkstyle-3.0.2     | 337 KB    | ##################################### | 100%
# ipython_genutils-0.2 | 27 KB     | ##################################### | 100%
# pure_eval-0.2.2      | 14 KB     | ##################################### | 100%
# appdirs-1.4.4        | 12 KB     | ##################################### | 100%
# sphinxcontrib-devhel | 23 KB     | ##################################### | 100%
# unidecode-1.2.0      | 155 KB    | ##################################### | 100%
# qtwebkit-5.212       | 14.3 MB   | ##################################### | 100%
# libclang-10.0.1      | 10.8 MB   | ##################################### | 100%
# lerc-3.0             | 196 KB    | ##################################### | 100%
# pillow-9.4.0         | 723 KB    | ##################################### | 100%
# ply-3.11             | 81 KB     | ##################################### | 100%
# qt-main-5.15.2       | 45.1 MB   | ##################################### | 100%
# babel-2.9.1          | 5.5 MB    | ##################################### | 100%
# libbrotlicommon-1.0. | 70 KB     | ##################################### | 100%
# lz4-c-1.9.4          | 154 KB    | ##################################### | 100%
# brotli-bin-1.0.9     | 19 KB     | ##################################### | 100%
# mkl-service-2.4.0    | 59 KB     | ##################################### | 100%
# parso-0.8.3          | 70 KB     | ##################################### | 100%
# certifi-2022.12.7    | 150 KB    | ##################################### | 100%
# jupyterlab_pygments- | 8 KB      | ##################################### | 100%
# setuptools-65.6.3    | 1.1 MB    | ##################################### | 100%
# pyopenssl-22.0.0     | 50 KB     | ##################################### | 100%
# psutil-5.9.0         | 330 KB    | ##################################### | 100%
# sip-6.6.2            | 425 KB    | ##################################### | 100%
# libedit-3.1.20221030 | 181 KB    | ##################################### | 100%
# python-3.8.16        | 23.7 MB   | ##################################### | 100%
# pandocfilters-1.5.0  | 11 KB     | ##################################### | 100%
# pexpect-4.8.0        | 53 KB     | ##################################### | 100%
# testpath-0.5.0       | 81 KB     | ##################################### | 100%
# jsonschema-3.2.0     | 47 KB     | ##################################### | 100%
# ld_impl_linux-64-2.3 | 654 KB    | ##################################### | 100%
# idna-3.3             | 49 KB     | ##################################### | 100%
# libtiff-4.5.0        | 479 KB    | ##################################### | 100%
# mkl_random-1.2.2     | 308 KB    | ##################################### | 100%
# openh264-2.1.1       | 711 KB    | ##################################### | 100%
# libtasn1-4.16.0      | 58 KB     | ##################################### | 100%
# cloudpickle-2.0.0    | 32 KB     | ##################################### | 100%
# wcwidth-0.2.5        | 26 KB     | ##################################### | 100%
# pip-23.0.1           | 2.5 MB    | ##################################### | 100%
# libuv-1.44.2         | 864 KB    | ##################################### | 100%
# libsodium-1.0.18     | 244 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: \ Ran pip subprocess with arguments:
# ['/opt/conda/envs/d3ke/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/jupyter/Deep-learning/condaenv.h2e8axa4.requirements.txt']
# Pip subprocess output:
# Collecting h5py==3.7.0
#   Downloading h5py-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 45.9 MB/s eta 0:00:00
# Collecting imageio==2.22.4
#   Downloading imageio-2.22.4-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 79.2 MB/s eta 0:00:00
# Collecting networkx==2.8.8
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.9 MB/s eta 0:00:00
# Collecting opencv-python==4.5.4.60
#   Downloading opencv_python-4.5.4.60-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 MB 18.0 MB/s eta 0:00:00
# Collecting pandas==1.4.1
#   Downloading pandas-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 92.6 MB/s eta 0:00:00
# Collecting pytorch-model-summary==0.1.2
#   Downloading pytorch_model_summary-0.1.2-py3-none-any.whl (9.3 kB)
# Collecting pywavelets==1.4.1
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 95.0 MB/s eta 0:00:00
# Collecting scikit-image==0.19.0
#   Downloading scikit_image-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 17.9 MB/s eta 0:00:00
# Collecting scipy==1.7.3
#   Downloading scipy-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 33.6 MB/s eta 0:00:00
# Collecting smplx==0.1.28
#   Downloading smplx-0.1.28-py3-none-any.whl (29 kB)
# Collecting tifffile==2022.10.10
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 26.0 MB/s eta 0:00:00
# Collecting tqdm==4.63.0
#   Downloading tqdm-4.63.0-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 11.4 MB/s eta 0:00:00
# Collecting transforms3d==0.4.1
#   Downloading transforms3d-0.4.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 65.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting trimesh==3.16.0
#   Downloading trimesh-3.16.0-py3-none-any.whl (660 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.6/660.6 kB 45.0 MB/s eta 0:00:00
# Collecting yacs==0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
#
# Pip subprocess error:
# ERROR: Could not find a version that satisfies the requirement pip==21.2.2=py38haa95532_0 (from versions: 0.2, 0.2.1, 0.3, 0.3.1, 0.4, 0.5, 0.5.1, 0.6, 0.6.1, 0.6.2, 0.6.3, 0.7, 0.7.1, 0.7.2, 0.8, 0.8.1, 0.8.2, 0.8.3, 1.0, 1.0.1, 1.0.2, 1.1, 1.2, 1.2.1, 1.3, 1.3.1, 1.4, 1.4.1, 1.5, 1.5.1, 1.5.2, 1.5.3, 1.5.4, 1.5.5, 1.5.6, 6.0, 6.0.1, 6.0.2, 6.0.3, 6.0.4, 6.0.5, 6.0.6, 6.0.7, 6.0.8, 6.1.0, 6.1.1, 7.0.0, 7.0.1, 7.0.2, 7.0.3, 7.1.0, 7.1.1, 7.1.2, 8.0.0, 8.0.1, 8.0.2, 8.0.3, 8.1.0, 8.1.1, 8.1.2, 9.0.0, 9.0.1, 9.0.2, 9.0.3, 10.0.0b1, 10.0.0b2, 10.0.0, 10.0.1, 18.0, 18.1, 19.0, 19.0.1, 19.0.2, 19.0.3, 19.1, 19.1.1, 19.2, 19.2.1, 19.2.2, 19.2.3, 19.3, 19.3.1, 20.0, 20.0.1, 20.0.2, 20.1b1, 20.1, 20.1.1, 20.2b1, 20.2, 20.2.1, 20.2.2, 20.2.3, 20.2.4, 20.3b1, 20.3, 20.3.1, 20.3.2, 20.3.3, 20.3.4, 21.0, 21.0.1, 21.1, 21.1.1, 21.1.2, 21.1.3, 21.2, 21.2.1, 21.2.2, 21.2.3, 21.2.4, 21.3, 21.3.1, 22.0, 22.0.1, 22.0.2, 22.0.3, 22.0.4, 22.1b1, 22.1, 22.1.1, 22.1.2, 22.2, 22.2.1, 22.2.2, 22.3, 22.3.1, 23.0, 23.0.1)
# ERROR: No matching distribution found for pip==21.2.2=py38haa95532_0
#
# failed
#
# CondaEnvException: Pip failed
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from ms_model_estimation.opensim.OpenSimModel import OpenSimModel
from ms_model_estimation.smplh.scalingIKInf import IKTaskSet, scalingIKSet, scaleSet
from ms_model_estimation.opensim.DataReader import DataReader
from ms_model_estimation.opensim.OSLabelGenerator import BMLAmassOpenSimGTGenerator
from ms_model_estimation.pyOpenSim.TrcGenerator import TrcGenerator
import pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/tmp/ipykernel_11267/3769842000.py in <module>
# ----> 1 from ms_model_estimation.opensim.OpenSimModel import OpenSimModel
#       2 from ms_model_estimation.smplh.scalingIKInf import IKTaskSet, scalingIKSet, scaleSet
#       3 from ms_model_estimation.opensim.DataReader import DataReader
#       4 from ms_model_estimation.opensim.OSLabelGenerator import BMLAmassOpenSimGTGenerator
#       5 from ms_model_estimation.pyOpenSim.TrcGenerator import TrcGenerator
#
# ModuleNotFoundError: No module named 'ms_model_estimation.opensim'

# %%
modelPath="D:/ms_model_estimation/dataset/opensim/BMLmovi/full_body.osim"
amassFolder="D:/mscWeitseYangLocal/dataset/amass/"
v3dFolder = "D:/mscWeitseYangLocal/dataset/BMLmovi/v3d/F/"

# %%
dataReader=DataReader()
ikset=dataReader.read_ik_set(IKTaskSet)
scalingIKSet=dataReader.read_ik_set(scalingIKSet)
scaleset=dataReader.read_scale_set(scaleSet)

# %%
gtGenerator=BMLAmassOpenSimGTGenerator(
    v3dFolder, amassFolder, modelPath, scaleset , scalingIKSet , ikset,
    reScale=True, reIK=True, scaleOnly=False
)

# %%
npzPathList=gtGenerator.traverse_npz_files("BMLmovi")

# %%
for path in npzPathList[:2]:
    gtGenerator.generate(path)

# %%
from ms_model_estimation import Postscaling_LockedCoordinates, Postscaling_UnlockedConstraints, ChangingParentMarkers

# %%
gtGenerator.opensimModel.postscaling_unlockedConstraints
# Out:
# ['sternoclavicular_r2_con',
#  'sternoclavicular_r3_con',
#  'acromioclavicular_r2_con',
#  'sternoclavicular_r2_con_l',
#  'sternoclavicular_r3_con_l',
#  'acromioclavicular_r2_con_l']
